# %%
from PIL import Image
import os
from collections import Counter
import time
def get_image_info(directory):
    image_info = []
    width_distribution = Counter()
    height_distribution = Counter()
    resolution_distribution = Counter()

    max_resolution = 0
    min_resolution = float('inf')
    max_res_file = ""
    min_res_file = ""

    max_width = 0
    min_width = float('inf')
    max_width_file = ""
    min_width_file = ""

    max_height = 0
    min_height = float('inf')
    max_height_file = ""
    min_height_file = ""

    for filename in os.listdir(directory):
        if filename.endswith('.jpg') or filename.endswith('.png'):
            path = os.path.join(directory, filename)
            with Image.open(path) as img:
                width, height = img.size
                resolution = img.width * img.height

                # 更新宽度统计
                if width > max_width:
                    max_width = width
                    max_width_file = filename
                if width < min_width:
                    min_width = width
                    min_width_file = filename

                # 更新高度统计
                if height > max_height:
                    max_height = height
                    max_height_file = filename
                if height < min_height:
                    min_height = height
                    min_height_file = filename

                # 更新分辨率统计
                if resolution > max_resolution:
                    max_resolution = resolution
                    max_res_file = filename
                
                if resolution < min_resolution:
                    min_resolution = resolution
                    min_res_file = filename

                # 分布统计
                width_distribution[width // 100 * 100] += 1
                height_distribution[height // 100 * 100] += 1
                resolution_distribution[resolution // 50000 * 50000] += 1

                # 收集图片信息
                info = {
                    'filename': filename,
                    'width': width,
                    'height': height,
                    'resolution': resolution
                }
                image_info.append(info)

    # 打印统计数据
    print("Width Distribution (by 100 pixels):")
    for w, count in sorted(width_distribution.items()):
        print(f"{w} to {w+99} pixels: {count} images")
    print(f"Max Width: {max_width} pixels (File: {max_width_file}), Min Width: {min_width} pixels (File: {min_width_file})")

    print("Height Distribution (by 100 pixels):")
    for h, count in sorted(height_distribution.items()):
        print(f"{h} to {h+99} pixels: {count} images")
    print(f"Max Height: {max_height} pixels (File: {max_height_file}), Min Height: {min_height} pixels (File: {min_height_file})")

    print("Resolution Distribution (by 1 MP):")
    for r, count in sorted(resolution_distribution.items()):
        print(f"{r} to {r+49999} pixels: {count} images")
    print(f"Max Resolution: {max_resolution} pixels (File: {max_res_file}), Min Resolution: {min_resolution} pixels (File: {min_res_file})")
    
    return image_info

# %%
from PIL import Image, ImageOps
import os
import time

def pad_images(directory, image_info, save_directory):
    idx = 0
    for info in image_info:
        path = os.path.join(directory, info['filename'])
        idx += 1
        if idx % 10 == 0:
            print(f"Padding images: {idx}/{len(image_info)} finished")
        with Image.open(path) as img:
            padding_width = int(img.width * 0.05)
            padding_height = int(img.height * 0.05)
            padded_img = ImageOps.expand(img, border=(padding_width, padding_height), fill='white')
            # 保存填充后的图片
            save_path = os.path.join(save_directory, f"padded_{info['filename']}")
            padded_img.save(save_path)
            
            
def resize_images(directory, target_height=256, save_directory='../data/resized'):
    file_list = [f for f in os.listdir(directory) if f.startswith('padded_')]
    idx = 0
    for filename in file_list:
        idx += 1
        if idx % 10 == 0:
            print(f"Resizing images: {idx}/{len(file_list)} finished")
        path = os.path.join(directory, filename)
        with Image.open(path) as img:
            aspect_ratio = img.width / img.height
            new_width = int(target_height * aspect_ratio)
            resized_img = img.resize((new_width, target_height), Image.ANTIALIAS)
            save_path = os.path.join(save_directory, f"{filename[len('padded_'):]}")
            resized_img.save(save_path)

# %%
def main():
    start_time = time.time()
    source_directory = '../data/testBdata/Test_B set/'
    padded_directory = '../data/testBdata/padding'
    resized_directory = '../data/testBdata/resized'
    
    # 确保保存目录存在
    os.makedirs(padded_directory, exist_ok=True)
    os.makedirs(resized_directory, exist_ok=True)
    
    # 获取图片信息
    image_info = get_image_info(source_directory)
    print(f"Image information collection completed. Time elapsed: {time.time() - start_time} seconds")
    
    # 应用padding并保存
    pad_images(source_directory, image_info, padded_directory)
    
    print(f"Padding completed. Time elapsed: {time.time() - start_time} seconds")
    
    # 从保存的padding图片读取，调整大小并保存
    resize_images(padded_directory, 128, resized_directory)
    
    print(f"Resizing completed. Total time elapsed: {time.time() - start_time} seconds")

    print("All processes are completed.")

main()
# Out:
# Width Distribution (by 100 pixels):
# 200 to 299 pixels: 4 images
# 300 to 399 pixels: 8 images
# 400 to 499 pixels: 27 images
# 500 to 599 pixels: 35 images
# 600 to 699 pixels: 56 images
# 700 to 799 pixels: 70 images
# 800 to 899 pixels: 93 images
# 900 to 999 pixels: 125 images
# 1000 to 1099 pixels: 108 images
# 1100 to 1199 pixels: 119 images
# 1200 to 1299 pixels: 121 images
# 1300 to 1399 pixels: 116 images
# 1400 to 1499 pixels: 110 images
# 1500 to 1599 pixels: 104 images
# 1600 to 1699 pixels: 98 images
# 1700 to 1799 pixels: 87 images
# 1800 to 1899 pixels: 77 images
# 1900 to 1999 pixels: 81 images
# 2000 to 2099 pixels: 85 images
# 2100 to 2199 pixels: 84 images
# 2200 to 2299 pixels: 60 images
# 2300 to 2399 pixels: 63 images
# 2400 to 2499 pixels: 39 images
# 2500 to 2599 pixels: 32 images
# 2600 to 2699 pixels: 28 images
# 2700 to 2799 pixels: 30 images
# 2800 to 2899 pixels: 40 images
# 2900 to 2999 pixels: 29 images
# 3000 to 3099 pixels: 25 images
# 3100 to 3199 pixels: 13 images
# 3200 to 3299 pixels: 12 images
# 3300 to 3399 pixels: 7 images
# 3400 to 3499 pixels: 3 images
# 3500 to 3599 pixels: 3 images
# 3600 to 3699 pixels: 3 images
# 3800 to 3899 pixels: 3 images
# 3900 to 3999 pixels: 1 images
# 4100 to 4199 pixels: 1 images
# Max Width: 4126 pixels (File: 0121154.png), Min Width: 273 pixels (File: 0044147.png)
# Height Distribution (by 100 pixels):
# 100 to 199 pixels: 63 images
# 200 to 299 pixels: 570 images
# 300 to 399 pixels: 441 images
# 400 to 499 pixels: 397 images
# 500 to 599 pixels: 236 images
# 600 to 699 pixels: 136 images
# 700 to 799 pixels: 70 images
# 800 to 899 pixels: 38 images
# 900 to 999 pixels: 27 images
# 1000 to 1099 pixels: 9 images
# 1100 to 1199 pixels: 3 images
# 1200 to 1299 pixels: 4 images
# 1300 to 1399 pixels: 1 images
# 1400 to 1499 pixels: 1 images
# 1500 to 1599 pixels: 2 images
# 1600 to 1699 pixels: 1 images
# 2000 to 2099 pixels: 1 images
# Max Height: 2053 pixels (File: 0085974.png), Min Height: 120 pixels (File: 0094203.png)
# Resolution Distribution (by 1 MP):
# 0 to 49999 pixels: 1 images
# 50000 to 99999 pixels: 19 images
# 100000 to 149999 pixels: 49 images
# 150000 to 199999 pixels: 93 images
# 200000 to 249999 pixels: 104 images
# 250000 to 299999 pixels: 124 images
# 300000 to 349999 pixels: 125 images
# 350000 to 399999 pixels: 132 images
# 400000 to 449999 pixels: 120 images
# 450000 to 499999 pixels: 118 images
# 500000 to 549999 pixels: 114 images
# 550000 to 599999 pixels: 83 images
# 600000 to 649999 pixels: 60 images
# 650000 to 699999 pixels: 77 images
# 700000 to 749999 pixels: 58 images
# 750000 to 799999 pixels: 76 images
# 800000 to 849999 pixels: 66 images
# 850000 to 899999 pixels: 62 images
# 900000 to 949999 pixels: 45 images
# 950000 to 999999 pixels: 52 images
# 1000000 to 1049999 pixels: 41 images
# 1050000 to 1099999 pixels: 29 images
# 1100000 to 1149999 pixels: 32 images
# 1150000 to 1199999 pixels: 42 images
# 1200000 to 1249999 pixels: 27 images
# 1250000 to 1299999 pixels: 24 images
# 1300000 to 1349999 pixels: 19 images
# 1350000 to 1399999 pixels: 23 images
# 1400000 to 1449999 pixels: 16 images
# 1450000 to 1499999 pixels: 18 images
# 1500000 to 1549999 pixels: 16 images
# 1550000 to 1599999 pixels: 18 images
# 1600000 to 1649999 pixels: 10 images
# 1650000 to 1699999 pixels: 18 images
# 1700000 to 1749999 pixels: 5 images
# 1750000 to 1799999 pixels: 6 images
# 1800000 to 1849999 pixels: 5 images
# 1850000 to 1899999 pixels: 8 images
# 1900000 to 1949999 pixels: 7 images
# 1950000 to 1999999 pixels: 4 images
# 2000000 to 2049999 pixels: 7 images
# 2050000 to 2099999 pixels: 3 images
# 2100000 to 2149999 pixels: 7 images
# 2150000 to 2199999 pixels: 2 images
# 2200000 to 2249999 pixels: 3 images
# 2250000 to 2299999 pixels: 1 images
# 2300000 to 2349999 pixels: 3 images
# 2400000 to 2449999 pixels: 1 images
# 2450000 to 2499999 pixels: 4 images
# 2500000 to 2549999 pixels: 1 images
# 2550000 to 2599999 pixels: 3 images
# 2600000 to 2649999 pixels: 3 images
# 2650000 to 2699999 pixels: 2 images
# 2700000 to 2749999 pixels: 2 images
# 2750000 to 2799999 pixels: 1 images
# 2950000 to 2999999 pixels: 1 images
# 3000000 to 3049999 pixels: 1 images
# 3100000 to 3149999 pixels: 1 images
# 3150000 to 3199999 pixels: 1 images
# 3200000 to 3249999 pixels: 1 images
# 3250000 to 3299999 pixels: 1 images
# 3300000 to 3349999 pixels: 1 images
# 3400000 to 3449999 pixels: 1 images
# 3450000 to 3499999 pixels: 1 images
# 3700000 to 3749999 pixels: 1 images
# 3800000 to 3849999 pixels: 1 images
# Max Resolution: 3837512 pixels (File: 0022799.png), Min Resolution: 48263 pixels (File: 0113176.png)
# Image information collection completed. Time elapsed: 0.09343624114990234 seconds
# Padding images: 10/2000 finished
# Padding images: 20/2000 finished
# Padding images: 30/2000 finished
# Padding images: 40/2000 finished
# Padding images: 50/2000 finished
# Padding images: 60/2000 finished
# Padding images: 70/2000 finished
# Padding images: 80/2000 finished
# Padding images: 90/2000 finished
# Padding images: 100/2000 finished
# Padding images: 110/2000 finished
# Padding images: 120/2000 finished
# Padding images: 130/2000 finished
# Padding images: 140/2000 finished
# Padding images: 150/2000 finished
# Padding images: 160/2000 finished
# Padding images: 170/2000 finished
# Padding images: 180/2000 finished
# Padding images: 190/2000 finished
# Padding images: 200/2000 finished
# Padding images: 210/2000 finished
# Padding images: 220/2000 finished
# Padding images: 230/2000 finished
# Padding images: 240/2000 finished
# Padding images: 250/2000 finished
# Padding images: 260/2000 finished
# Padding images: 270/2000 finished
# Padding images: 280/2000 finished
# Padding images: 290/2000 finished
# Padding images: 300/2000 finished
# Padding images: 310/2000 finished
# Padding images: 320/2000 finished
# Padding images: 330/2000 finished
# Padding images: 340/2000 finished
# Padding images: 350/2000 finished
# Padding images: 360/2000 finished
# Padding images: 370/2000 finished
# Padding images: 380/2000 finished
# Padding images: 390/2000 finished
# Padding images: 400/2000 finished
# Padding images: 410/2000 finished
# Padding images: 420/2000 finished
# Padding images: 430/2000 finished
# Padding images: 440/2000 finished
# Padding images: 450/2000 finished
# Padding images: 460/2000 finished
# Padding images: 470/2000 finished
# Padding images: 480/2000 finished
# Padding images: 490/2000 finished
# Padding images: 500/2000 finished
# Padding images: 510/2000 finished
# Padding images: 520/2000 finished
# Padding images: 530/2000 finished
# Padding images: 540/2000 finished
# Padding images: 550/2000 finished
# Padding images: 560/2000 finished
# Padding images: 570/2000 finished
# Padding images: 580/2000 finished
# Padding images: 590/2000 finished
# Padding images: 600/2000 finished
# Padding images: 610/2000 finished
# Padding images: 620/2000 finished
# Padding images: 630/2000 finished
# Padding images: 640/2000 finished
# Padding images: 650/2000 finished
# Padding images: 660/2000 finished
# Padding images: 670/2000 finished
# Padding images: 680/2000 finished
# Padding images: 690/2000 finished
# Padding images: 700/2000 finished
# Padding images: 710/2000 finished
# Padding images: 720/2000 finished
# Padding images: 730/2000 finished
# Padding images: 740/2000 finished
# Padding images: 750/2000 finished
# Padding images: 760/2000 finished
# Padding images: 770/2000 finished
# Padding images: 780/2000 finished
# Padding images: 790/2000 finished
# Padding images: 800/2000 finished
# Padding images: 810/2000 finished
# Padding images: 820/2000 finished
# Padding images: 830/2000 finished
# Padding images: 840/2000 finished
# Padding images: 850/2000 finished
# Padding images: 860/2000 finished
# Padding images: 870/2000 finished
# Padding images: 880/2000 finished
# Padding images: 890/2000 finished
# Padding images: 900/2000 finished
# Padding images: 910/2000 finished
# Padding images: 920/2000 finished
# Padding images: 930/2000 finished
# Padding images: 940/2000 finished
# Padding images: 950/2000 finished
# Padding images: 960/2000 finished
# Padding images: 970/2000 finished
# Padding images: 980/2000 finished
# Padding images: 990/2000 finished
# Padding images: 1000/2000 finished
# Padding images: 1010/2000 finished
# Padding images: 1020/2000 finished
# Padding images: 1030/2000 finished
# Padding images: 1040/2000 finished
# Padding images: 1050/2000 finished
# Padding images: 1060/2000 finished
# Padding images: 1070/2000 finished
# Padding images: 1080/2000 finished
# Padding images: 1090/2000 finished
# Padding images: 1100/2000 finished
# Padding images: 1110/2000 finished
# Padding images: 1120/2000 finished
# Padding images: 1130/2000 finished
# Padding images: 1140/2000 finished
# Padding images: 1150/2000 finished
# Padding images: 1160/2000 finished
# Padding images: 1170/2000 finished
# Padding images: 1180/2000 finished
# Padding images: 1190/2000 finished
# Padding images: 1200/2000 finished
# Padding images: 1210/2000 finished
# Padding images: 1220/2000 finished
# Padding images: 1230/2000 finished
# Padding images: 1240/2000 finished
# Padding images: 1250/2000 finished
# Padding images: 1260/2000 finished
# Padding images: 1270/2000 finished
# Padding images: 1280/2000 finished
# Padding images: 1290/2000 finished
# Padding images: 1300/2000 finished
# Padding images: 1310/2000 finished
# Padding images: 1320/2000 finished
# Padding images: 1330/2000 finished
# Padding images: 1340/2000 finished
# Padding images: 1350/2000 finished
# Padding images: 1360/2000 finished
# Padding images: 1370/2000 finished
# Padding images: 1380/2000 finished
# Padding images: 1390/2000 finished
# Padding images: 1400/2000 finished
# Padding images: 1410/2000 finished
# Padding images: 1420/2000 finished
# Padding images: 1430/2000 finished
# Padding images: 1440/2000 finished
# Padding images: 1450/2000 finished
# Padding images: 1460/2000 finished
# Padding images: 1470/2000 finished
# Padding images: 1480/2000 finished
# Padding images: 1490/2000 finished
# Padding images: 1500/2000 finished
# Padding images: 1510/2000 finished
# Padding images: 1520/2000 finished
# Padding images: 1530/2000 finished
# Padding images: 1540/2000 finished
# Padding images: 1550/2000 finished
# Padding images: 1560/2000 finished
# Padding images: 1570/2000 finished
# Padding images: 1580/2000 finished
# Padding images: 1590/2000 finished
# Padding images: 1600/2000 finished
# Padding images: 1610/2000 finished
# Padding images: 1620/2000 finished
# Padding images: 1630/2000 finished
# Padding images: 1640/2000 finished
# Padding images: 1650/2000 finished
# Padding images: 1660/2000 finished
# Padding images: 1670/2000 finished
# Padding images: 1680/2000 finished
# Padding images: 1690/2000 finished
# Padding images: 1700/2000 finished
# Padding images: 1710/2000 finished
# Padding images: 1720/2000 finished
# Padding images: 1730/2000 finished
# Padding images: 1740/2000 finished
# Padding images: 1750/2000 finished
# Padding images: 1760/2000 finished
# Padding images: 1770/2000 finished
# Padding images: 1780/2000 finished
# Padding images: 1790/2000 finished
# Padding images: 1800/2000 finished
# Padding images: 1810/2000 finished
# Padding images: 1820/2000 finished
# Padding images: 1830/2000 finished
# Padding images: 1840/2000 finished
# Padding images: 1850/2000 finished
# Padding images: 1860/2000 finished
# Padding images: 1870/2000 finished
# Padding images: 1880/2000 finished
# Padding images: 1890/2000 finished
# Padding images: 1900/2000 finished
# Padding images: 1910/2000 finished
# Padding images: 1920/2000 finished
# Padding images: 1930/2000 finished
# Padding images: 1940/2000 finished
# Padding images: 1950/2000 finished
# Padding images: 1960/2000 finished
# Padding images: 1970/2000 finished
# Padding images: 1980/2000 finished
# Padding images: 1990/2000 finished
# Padding images: 2000/2000 finished
# Padding completed. Time elapsed: 109.75618696212769 seconds
# Resizing images: 10/2000 finished
# Resizing images: 20/2000 finished
# Resizing images: 30/2000 finished
# Resizing images: 40/2000 finished
# Resizing images: 50/2000 finished
# Resizing images: 60/2000 finished
# Resizing images: 70/2000 finished
# Resizing images: 80/2000 finished
# Resizing images: 90/2000 finished
# Resizing images: 100/2000 finished
# Resizing images: 110/2000 finished
# Resizing images: 120/2000 finished
# Resizing images: 130/2000 finished
# Resizing images: 140/2000 finished
# Resizing images: 150/2000 finished
# Resizing images: 160/2000 finished
# Resizing images: 170/2000 finished
# Resizing images: 180/2000 finished
# Resizing images: 190/2000 finished
# Resizing images: 200/2000 finished
# Resizing images: 210/2000 finished
# Resizing images: 220/2000 finished
# Resizing images: 230/2000 finished
# Resizing images: 240/2000 finished
# Resizing images: 250/2000 finished
# Resizing images: 260/2000 finished
# Resizing images: 270/2000 finished
# Resizing images: 280/2000 finished
# Resizing images: 290/2000 finished
# Resizing images: 300/2000 finished
# Resizing images: 310/2000 finished
# Resizing images: 320/2000 finished
# Resizing images: 330/2000 finished
# Resizing images: 340/2000 finished
# Resizing images: 350/2000 finished
# Resizing images: 360/2000 finished
# Resizing images: 370/2000 finished
# Resizing images: 380/2000 finished
# Resizing images: 390/2000 finished
# Resizing images: 400/2000 finished
# Resizing images: 410/2000 finished
# Resizing images: 420/2000 finished
# Resizing images: 430/2000 finished
# Resizing images: 440/2000 finished
# Resizing images: 450/2000 finished
# Resizing images: 460/2000 finished
# Resizing images: 470/2000 finished
# Resizing images: 480/2000 finished
# Resizing images: 490/2000 finished
# Resizing images: 500/2000 finished
# Resizing images: 510/2000 finished
# Resizing images: 520/2000 finished
# Resizing images: 530/2000 finished
# Resizing images: 540/2000 finished
# Resizing images: 550/2000 finished
# Resizing images: 560/2000 finished
# Resizing images: 570/2000 finished
# Resizing images: 580/2000 finished
# Resizing images: 590/2000 finished
# Resizing images: 600/2000 finished
# Resizing images: 610/2000 finished
# Resizing images: 620/2000 finished
# Resizing images: 630/2000 finished
# Resizing images: 640/2000 finished
# Resizing images: 650/2000 finished
# Resizing images: 660/2000 finished
# Resizing images: 670/2000 finished
# Resizing images: 680/2000 finished
# Resizing images: 690/2000 finished
# Resizing images: 700/2000 finished
# Resizing images: 710/2000 finished
# Resizing images: 720/2000 finished
# Resizing images: 730/2000 finished
# Resizing images: 740/2000 finished
# Resizing images: 750/2000 finished
# Resizing images: 760/2000 finished
# Resizing images: 770/2000 finished
# Resizing images: 780/2000 finished
# Resizing images: 790/2000 finished
# Resizing images: 800/2000 finished
# Resizing images: 810/2000 finished
# Resizing images: 820/2000 finished
# Resizing images: 830/2000 finished
# Resizing images: 840/2000 finished
# Resizing images: 850/2000 finished
# Resizing images: 860/2000 finished
# Resizing images: 870/2000 finished
# Resizing images: 880/2000 finished
# Resizing images: 890/2000 finished
# Resizing images: 900/2000 finished
# Resizing images: 910/2000 finished
# Resizing images: 920/2000 finished
# Resizing images: 930/2000 finished
# Resizing images: 940/2000 finished
# Resizing images: 950/2000 finished
# Resizing images: 960/2000 finished
# Resizing images: 970/2000 finished
# Resizing images: 980/2000 finished
# Resizing images: 990/2000 finished
# Resizing images: 1000/2000 finished
# Resizing images: 1010/2000 finished
# Resizing images: 1020/2000 finished
# Resizing images: 1030/2000 finished
# Resizing images: 1040/2000 finished
# Resizing images: 1050/2000 finished
# Resizing images: 1060/2000 finished
# Resizing images: 1070/2000 finished
# Resizing images: 1080/2000 finished
# Resizing images: 1090/2000 finished
# Resizing images: 1100/2000 finished
# Resizing images: 1110/2000 finished
# Resizing images: 1120/2000 finished
# Resizing images: 1130/2000 finished
# Resizing images: 1140/2000 finished
# Resizing images: 1150/2000 finished
# Resizing images: 1160/2000 finished
# Resizing images: 1170/2000 finished
# Resizing images: 1180/2000 finished
# Resizing images: 1190/2000 finished
# Resizing images: 1200/2000 finished
# Resizing images: 1210/2000 finished
# Resizing images: 1220/2000 finished
# Resizing images: 1230/2000 finished
# Resizing images: 1240/2000 finished
# Resizing images: 1250/2000 finished
# Resizing images: 1260/2000 finished
# Resizing images: 1270/2000 finished
# Resizing images: 1280/2000 finished
# Resizing images: 1290/2000 finished
# Resizing images: 1300/2000 finished
# Resizing images: 1310/2000 finished
# Resizing images: 1320/2000 finished
# Resizing images: 1330/2000 finished
# Resizing images: 1340/2000 finished
# Resizing images: 1350/2000 finished
# Resizing images: 1360/2000 finished
# Resizing images: 1370/2000 finished
# Resizing images: 1380/2000 finished
# Resizing images: 1390/2000 finished
# Resizing images: 1400/2000 finished
# Resizing images: 1410/2000 finished
# Resizing images: 1420/2000 finished
# Resizing images: 1430/2000 finished
# Resizing images: 1440/2000 finished
# Resizing images: 1450/2000 finished
# Resizing images: 1460/2000 finished
# Resizing images: 1470/2000 finished
# Resizing images: 1480/2000 finished
# Resizing images: 1490/2000 finished
# Resizing images: 1500/2000 finished
# Resizing images: 1510/2000 finished
# Resizing images: 1520/2000 finished
# Resizing images: 1530/2000 finished
# Resizing images: 1540/2000 finished
# Resizing images: 1550/2000 finished
# Resizing images: 1560/2000 finished
# Resizing images: 1570/2000 finished
# Resizing images: 1580/2000 finished
# Resizing images: 1590/2000 finished
# Resizing images: 1600/2000 finished
# Resizing images: 1610/2000 finished
# Resizing images: 1620/2000 finished
# Resizing images: 1630/2000 finished
# Resizing images: 1640/2000 finished
# Resizing images: 1650/2000 finished
# Resizing images: 1660/2000 finished
# Resizing images: 1670/2000 finished
# Resizing images: 1680/2000 finished
# Resizing images: 1690/2000 finished
# Resizing images: 1700/2000 finished
# Resizing images: 1710/2000 finished
# Resizing images: 1720/2000 finished
# Resizing images: 1730/2000 finished
# Resizing images: 1740/2000 finished
# Resizing images: 1750/2000 finished
# Resizing images: 1760/2000 finished
# Resizing images: 1770/2000 finished
# Resizing images: 1780/2000 finished
# Resizing images: 1790/2000 finished
# Resizing images: 1800/2000 finished
# Resizing images: 1810/2000 finished
# Resizing images: 1820/2000 finished
# Resizing images: 1830/2000 finished
# Resizing images: 1840/2000 finished
# Resizing images: 1850/2000 finished
# Resizing images: 1860/2000 finished
# Resizing images: 1870/2000 finished
# Resizing images: 1880/2000 finished
# Resizing images: 1890/2000 finished
# Resizing images: 1900/2000 finished
# Resizing images: 1910/2000 finished
# Resizing images: 1920/2000 finished
# Resizing images: 1930/2000 finished
# Resizing images: 1940/2000 finished
# Resizing images: 1950/2000 finished
# Resizing images: 1960/2000 finished
# Resizing images: 1970/2000 finished
# Resizing images: 1980/2000 finished
# Resizing images: 1990/2000 finished
# Resizing images: 2000/2000 finished
# Resizing completed. Total time elapsed: 163.35219764709473 seconds
# All processes are completed.

# %%
import json
def make_test_caption(img_path,caption_path):
     # 检查路径是否存在
    
    if not os.path.exists(img_path):
        raise FileNotFoundError(f"Image path {img_path} does not exist.")
    
    captions = []
    img_files = [f.split(".")[0] for f  in os.listdir(img_path)]
    
    for img_file in img_files:
        # test no caption 
        captions.append([img_file, ". . . ."])

    
    print("Loading data count:",len(captions))
    with open(os.path.join(caption_path,'caption.txt'), 'w') as file:
        for row in captions:
            file.write(f"{row[0]}\t{row[1]}\n")

# %%
def make_gray(source_dir, gray_dir,isgray=True):

    

    # 获取所有文件的列表
    files = [f for f in os.listdir(source_dir) if os.path.isfile(os.path.join(source_dir, f))]
    
    gray_files = files
    
    # 创建目标目录
    os.makedirs(gray_dir, exist_ok=True)
    
    # resize image to small than 32e4 
    def convert_and_save(source_file, dest_file):
        with Image.open(source_file) as img:
            width, height = img.size
     
            # resize every image height to 128
            if True:
                new_width = int(width )
                new_height = int(height )
            img = img.resize((new_width, new_height), Image.ANTIALIAS)
            
            if isgray:
                gray_img = img.convert('L')
                gray_img.save(dest_file, format='BMP')
            else:
                img.save(dest_file, format='png')
  
    # 移动文件到相应的目录，并转换为灰度图和BMP格式
    for f in files:
        source_file = os.path.join(source_dir, f)
        if isgray:
            dest_file = os.path.join(gray_dir, f.replace('.png', '.bmp'))
        else:
            dest_file = os.path.join(gray_dir, f)
        convert_and_save(source_file, dest_file)

    
    print(f'Total files: {len(files)}')

# %%
make_gray('../data/testBdata/resized','../data/testBdata/gray/img')
# Out:
# Total files: 2000

# %%
make_test_caption('../data/testBdata/gray/img','../data/testBdata/gray')
# Out:
# Loading data count: 2000
